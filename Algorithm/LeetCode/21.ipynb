# %% [markdown]
# ### [LeetCode]21. Merge Two Sorted Lists
# ***
# - **Problem**
# ***
# > **Merge two sorted linked lists and return it as a sorted list. The list should be made by splicing together the nodes of the first two lists.**
# ***
# > ***Example 1***
# > **Input:l1 = [1,2,4], l2 = [1,3,4]
# > ![image.png](attachment:image.png)
# > Output: [1,1,2,3,4,4]**
# ***
# > ***Example 2:***
# > **Input: l1 = [], l2 = []
# > Output: []**
# ***
# > ***Example 3:***
# > **Input: l1 = [], l2 = [0]
# > Output: [0]**
# ***
# > ***Constraints:***
# > **1) The number of nodes in both lists is in the range [0, 50].
# > 2) -100 <= Node.val <= 100
# > 3) Both l1 and l2 are sorted in non-decreasing order.**
# ***
# - **Solve**
# ____

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def mergeTwoLists(self, l1: ListNode, l2: ListNode) -> ListNode:
        l3 = ListNode()
        l1node , l2node = l1, l2
        if l1node.val >= l2node.val :
            l3.append(l1node.val)
            l1node = l1node.next
        if l2node.val >= l1node.val :
            l3.append(l2node.val)
            l2node = l2node.next
        
        return l3

# %% [markdown]
# 연결리스트에서는 append를 쓸수 없음. 망

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def mergeTwoLists(self, l1: ListNode, l2: ListNode) -> ListNode:
        l3 = ListNode()
        l1node , l2node, l3node = l1, l2, l3
        while l1 or l2:
            if l1node.val >= l2node.val :
                l3node,l1node = l1node, l1node.next
                l3node = l3node.next
            if l2node.val >= l1node.val :
                l3node,l2node = l2node, l2node.next
                l3node = l3node.next
        
        return l3

# %% [markdown]
# 돌아가지 않음.. 망..
